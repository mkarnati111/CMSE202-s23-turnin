# %% [markdown]
# # CMSE 202 Midterm S23 (Sect. 002)
#
# The goal of this midterm is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources:** This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This midterm is designed to give you the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the midterm.
#
# You are encouraged to look through the entire exam before you get started so that you can appropriately budget your time and understand the broad goals of the exam.
#
# If you have any questions during the exam, you may ask the instructor, the TA, or the LA privately; simply raise your hand and one of us will come over to you.
#
# ### Content Knowledge Tested
# - Using Github to save and track progress on your work
# - Using Pandas to read, manipulate, and access data files
# - Using documentation and examples to effectively utilitze unfamiliar Python packages
# - Writing new classes to effectively store complex datasets

# %% [markdown]
# ## Part 0: Add to your Git repository to track your progress on your exam (10 points total)
#
# Before you get to far along in the exam, you're going to add it to the `cmse202-S23-turnin` repository you created in class so that you can track your progress on the exam and preserve the final version that you turn in. In order to do this you need to
#
# ### &#9989; Part 0.1 (5 points):
#
# 1. Navigate to your `cmse202-S23-turnin` repository and create a new directory called `midterm`.
# 2. Move this notebook into that **new directory** in your repository, then **add it and commit it to your repository**.
# 1. Finally, to test that everything is working, "git push" the file so that it ends up in your GitHub repository.
#
# **Important**: Double check you've added your Professor and your TA as collaborators to your "turnin" respository (you should have done this in the previous homework assignment).
#
# **Also important**: Make sure that the version of this notebook that you are working on is the same one that you just added to your repository! If you are working on a different copy of the noteobok, **none of your changes will be tracked**!
#
# The file should now show up on your GitHub account in the `cmse202-S23-turnin` repository inside the `midterm` directory you just created.  Periodically, **you'll be asked to commit your changes to the repository and push them to the remote GitHub location**. It can be good to get into a habit of committing your changes any time you make a significant modification.
#
# ### Part 0.2 (2 points):
# &#9989; Before you move on, **put the command(s) that your instructor should run to clone your repository in the markdown cell below.**

# %%
#Write your code here
git clone https://github.com/mkarnati111/CMSE202-s23-turnin.git

# %% [markdown]
# ## Part 1: Getting Data with Curl ( points)
#
# For this exam, you will be working with a dataset that contains **spectra.** Spectra are what you get when you separate light–like in a prism–and measure the flux (fancy word for brightness) of the different parts of the light (E.g., blue has a flux of 400, red has a flux of 600, etc.). More specifically, we measure the *wavelength* of the light (shorter wavelengths = bluer, longer wavelengths=redder). The data we’ll be working with came from a space telescope looking at different astronomical sources.
#
# For this exam, you only need to know that wavelength and flux are measured values used in astronomy, physics, chemistry, and biology.
#
#
# First, let’s get our data files.
#
# &#9989; **Download the files using `curl` and the following links. Put the commands you used to download the files in the cell below.**
#
# - `https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S23-data/main/midterm/metadata.csv`
# - `https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S23-data/main/midterm/flux_values.csv`
# - `https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S23-data/main/midterm/wavlength_values.csv`

# %%
#Write your code here
curl -O https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S23-data/main/midterm/metadata.csv
curl -O https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S23-data/main/midterm/flux_values.csv
curl -O https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S23-data/main/midterm/wavlength_values.csv

# %% [markdown]
# ## Part 2: Reading the Data (5 points)
#
# &#9989; **Read in the data files using Pandas (put your code in the cell below).** One of them has metadata about each source, one of them has flux values for each source, and the last one has the wavelength values for each source.

# %%
#Write your code here
import pandas as pd
flux_df=pd.read_csv("flux_values.csv")
meta_df=pd.read_csv("metadata.csv")
wave_df=pd.read_csv("wavlength_values.csv")
meta_df
# Out:
#              ID      RA     DEC  Scale Factor
# 0    12043-6225  12.073 -62.428  1.250000e-16
# 1    12063-6259  12.106 -62.987  2.970000e-16
# 2    12073-6233  12.123 -62.554  3.130000e-15
# 3    12148-6741  12.247 -67.683  1.730000e-15
# 4    12216-6218  12.360 -62.303  2.180000e-16
# ..          ...     ...     ...           ...
# 526  23491+6243  23.819  62.732  2.220000e-16
# 527  23496+6131  23.827  61.526  1.250000e-15
# 528  23528+4821  23.881  48.360  5.740000e-16
# 529  23541+7031  23.902  70.526  4.120000e-16
# 530  23564-5651  23.941 -56.854  4.840000e-16
#
# [531 rows x 4 columns]

# %% [markdown]
# ## Part 3: Using a "New" Package (15 points)
# For this problem, we want you to use a new package that you aren’t as used to. Specifically, you’ll be using the [Seaborn plotting package](https://seaborn.pydata.org/).
#
# &#9989; RA and DEC are two measurements that are equivalent to latitude and longitude on earth (I.e., they give the position on the sky). **Use the Seaborn `relplot` and your metadata dataframe to make a scatter plot of the following:**
#
# - RA on the x-axis
# - DEC on the y-axis
# - The size of your data points on the plot should correspond to the scale factor (a measure of total brightness of the source.)
#
# **Hint:** You might want to take a look at the Seaborn example gallery.

# %%
#Write your code here
import seaborn as sns
sns.relplot(data=meta_df, x='RA', y='DEC', size= "Scale Factor")

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 4: Accessing Specific Data Values with Pandas (25 points)
#
# For this part of the exam, we’ll walk through how to use Pandas to access specific pieces of information in our dataframes.
#
# ### 4.1 Getting the Metadata (5 points)
#
# &#9989; **Use Pandas to access the value in the the 3rd row and 2nd column in the metadata dataframe (I.e., the RA for 12073-6233).** *Hint: What is the easiest way to access data using index values?*

# %%
#Write your code here
val = meta_df.iloc[2, 1]
print(val)
meta_df
# Out:
# 12.123
#              ID      RA     DEC  Scale Factor
# 0    12043-6225  12.073 -62.428  1.250000e-16
# 1    12063-6259  12.106 -62.987  2.970000e-16
# 2    12073-6233  12.123 -62.554  3.130000e-15
# 3    12148-6741  12.247 -67.683  1.730000e-15
# 4    12216-6218  12.360 -62.303  2.180000e-16
# ..          ...     ...     ...           ...
# 526  23491+6243  23.819  62.732  2.220000e-16
# 527  23496+6131  23.827  61.526  1.250000e-15
# 528  23528+4821  23.881  48.360  5.740000e-16
# 529  23541+7031  23.902  70.526  4.120000e-16
# 530  23564-5651  23.941 -56.854  4.840000e-16
#
# [531 rows x 4 columns]

# %% [markdown]
# ### 4.2 Getting Flux Data (10 Points)
#
# &#9989; **Use Pandas to access the entire second column of data in the flux dataframe (I.e., all flux values for 12063-6259).** Try to use the same tools as the previous problem.

# %%
#Write your code here
f_vals = flux_df.iloc[:, 1]
f_vals
# Out:
# 0     7660.9990
# 1     7906.7840
# 2     7821.8984
# 3     7240.5156
# 4     6555.7860
#         ...
# 88    7084.0360
# 89    6971.7830
# 90    7015.5747
# 91    6962.2200
# 92    6263.4400
# Name: 12063-6259, Length: 93, dtype: float64

# %% [markdown]
# ### 4.3 Getting Wavelength Data (10 Points)
#
# &#9989; **Use Pandas to access the entire third column of data in the wavelength dataframe (I.e., all wavelength values for 12073-6233).** Try to use the same tools as the previous two parts.

# %%
#Write your code here
w_vals = wave_df.iloc[:, 2]
w_vals
# Out:
# 0      7.864406
# 1      8.041659
# 2      8.230711
# 3      8.400978
# 4      8.574238
#         ...
# 88    22.185389
# 89    22.358518
# 90    22.558641
# 91    22.741007
# 92    22.916100
# Name: 12073-6233, Length: 93, dtype: float64

# %% [markdown]
# ## Part 5: Designing a Class (15 points)
#
# The issue with this dataset is that it comes in two parts: the spectra and the metadata for each source. To make life easier, we’re going to combine both the data and the metadata by designing a new class, the `spectrum` class.
#
# &#9989; **Write a new class for this spectrum data.** Your class should have the following:
# - Attributes for each piece of information in the metadata file (I.e., ID, RA, DEC, and Scale Factor)
# - Wavelengths
# - Flux
# - `get`-methods for both wavelength and flux (for the sake of time, you don’t need to write `set`-methods or `get`-methods for any of the other attributes).

# %%
#Write class here
class Spectrum:
    def __init__(self,ID,RA,DEC,SF,wavelength, flux):
        self.ID=ID
        self.RA=RA
        self.DEC=DEC
        self.SF=SF
        self.wavelength=wavelength
        self.flux=flux
    def get_wavelength(self):
        return self.wavelength
    def get_flux(self):
        return self.flux

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 6: Building Objects (15 points)
#
# &#9989; **Construct `spectra` objects for all of the spectral measurements. Append all of the objects to a new list called `spectrum_objects`.**

# %%
#Write your code here
spectrum_objects=[]
for index, row in meta_df.iterrows():
    spectrum = Spectrum(row['ID'], row['RA'], row['DEC'], row['Scale Factor'], wave_df.loc[:,row['ID']], flux_df.loc[:,row['ID']])
    spectrum_objects.append(spectrum)
    

spectrum_objects
# Out:
# [<__main__.Spectrum at 0x7f33821ac520>,
#  <__main__.Spectrum at 0x7f33821b5d60>,
#  <__main__.Spectrum at 0x7f3382264280>,
#  <__main__.Spectrum at 0x7f33821b5d30>,
#  <__main__.Spectrum at 0x7f33823547c0>,
#  <__main__.Spectrum at 0x7f338222ed30>,
#  <__main__.Spectrum at 0x7f3382354730>,
#  <__main__.Spectrum at 0x7f33821c80d0>,
#  <__main__.Spectrum at 0x7f33821c8610>,
#  <__main__.Spectrum at 0x7f33821c8760>,
#  <__main__.Spectrum at 0x7f33821c88b0>,
#  <__main__.Spectrum at 0x7f33821c8a00>,
#  <__main__.Spectrum at 0x7f33821c8b50>,
#  <__main__.Spectrum at 0x7f33821c8ca0>,
#  <__main__.Spectrum at 0x7f33821c8df0>,
#  <__main__.Spectrum at 0x7f33821c8f40>,
#  <__main__.Spectrum at 0x7f33821dd130>,
#  <__main__.Spectrum at 0x7f33821dd280>,
#  <__main__.Spectrum at 0x7f33821dd3d0>,
#  <__main__.Spectrum at 0x7f33821dd520>,
#  <__main__.Spectrum at 0x7f33821dd670>,
#  <__main__.Spectrum at 0x7f33821dd7c0>,
#  <__main__.Spectrum at 0x7f33821dd910>,
#  <__main__.Spectrum at 0x7f33821dda60>,
#  <__main__.Spectrum at 0x7f33821ddbb0>,
#  <__main__.Spectrum at 0x7f33821ddd00>,
#  <__main__.Spectrum at 0x7f33821dde50>,
#  <__main__.Spectrum at 0x7f33821ddfa0>,
#  <__main__.Spectrum at 0x7f338216b070>,
#  <__main__.Spectrum at 0x7f338216b1c0>,
#  <__main__.Spectrum at 0x7f338216b310>,
#  <__main__.Spectrum at 0x7f338216b460>,
#  <__main__.Spectrum at 0x7f338216b5b0>,
#  <__main__.Spectrum at 0x7f338216b700>,
#  <__main__.Spectrum at 0x7f338216b850>,
#  <__main__.Spectrum at 0x7f338216b9a0>,
#  <__main__.Spectrum at 0x7f338216baf0>,
#  <__main__.Spectrum at 0x7f338216bc40>,
#  <__main__.Spectrum at 0x7f3386d5bf10>,
#  <__main__.Spectrum at 0x7f338216bee0>,
#  <__main__.Spectrum at 0x7f338226f880>,
#  <__main__.Spectrum at 0x7f33821c30d0>,
#  <__main__.Spectrum at 0x7f338216bd90>,
#  <__main__.Spectrum at 0x7f33821c3430>,
#  <__main__.Spectrum at 0x7f3386c32220>,
#  <__main__.Spectrum at 0x7f33821c3220>,
#  <__main__.Spectrum at 0x7f33821c3520>,
#  <__main__.Spectrum at 0x7f33821c3670>,
#  <__main__.Spectrum at 0x7f33821c37c0>,
#  <__main__.Spectrum at 0x7f33821c3910>,
#  <__main__.Spectrum at 0x7f33821c3a60>,
#  <__main__.Spectrum at 0x7f33821c3bb0>,
#  <__main__.Spectrum at 0x7f33821c3d00>,
#  <__main__.Spectrum at 0x7f33821c3e50>,
#  <__main__.Spectrum at 0x7f33821c3fa0>,
#  <__main__.Spectrum at 0x7f33821c32e0>,
#  <__main__.Spectrum at 0x7f3382173070>,
#  <__main__.Spectrum at 0x7f33821731c0>,
#  <__main__.Spectrum at 0x7f3382173310>,
#  <__main__.Spectrum at 0x7f33821735b0>,
#  <__main__.Spectrum at 0x7f3382173850>,
#  <__main__.Spectrum at 0x7f3382173460>,
#  <__main__.Spectrum at 0x7f3382173700>,
#  <__main__.Spectrum at 0x7f3382173be0>,
#  <__main__.Spectrum at 0x7f3382173d30>,
#  <__main__.Spectrum at 0x7f3382173e80>,
#  <__main__.Spectrum at 0x7f3382173fd0>,
#  <__main__.Spectrum at 0x7f338217a160>,
#  <__main__.Spectrum at 0x7f338217a2b0>,
#  <__main__.Spectrum at 0x7f338217a400>,
#  <__main__.Spectrum at 0x7f338217a550>,
#  <__main__.Spectrum at 0x7f338217a6a0>,
#  <__main__.Spectrum at 0x7f338217a7f0>,
#  <__main__.Spectrum at 0x7f338217a940>,
#  <__main__.Spectrum at 0x7f338217aa90>,
#  <__main__.Spectrum at 0x7f338217abe0>,
#  <__main__.Spectrum at 0x7f338217ad30>,
#  <__main__.Spectrum at 0x7f338217ae80>,
#  <__main__.Spectrum at 0x7f338217afd0>,
#  <__main__.Spectrum at 0x7f33821b59d0>,
#  <__main__.Spectrum at 0x7f33821822b0>,
#  <__main__.Spectrum at 0x7f33821b5b80>,
#  <__main__.Spectrum at 0x7f3382182550>,
#  <__main__.Spectrum at 0x7f3382182160>,
#  <__main__.Spectrum at 0x7f3382182400>,
#  <__main__.Spectrum at 0x7f33821826a0>,
#  <__main__.Spectrum at 0x7f33821827f0>,
#  <__main__.Spectrum at 0x7f3382182940>,
#  <__main__.Spectrum at 0x7f3382182a90>,
#  <__main__.Spectrum at 0x7f3382182be0>,
#  <__main__.Spectrum at 0x7f3382182d30>,
#  <__main__.Spectrum at 0x7f3382182e80>,
#  <__main__.Spectrum at 0x7f3382182fd0>,
#  <__main__.Spectrum at 0x7f3382189160>,
#  <__main__.Spectrum at 0x7f33821892b0>,
#  <__main__.Spectrum at 0x7f3382189400>,
#  <__main__.Spectrum at 0x7f3382189550>,
#  <__main__.Spectrum at 0x7f33821896a0>,
#  <__main__.Spectrum at 0x7f33821897f0>,
#  <__main__.Spectrum at 0x7f3382189940>,
#  <__main__.Spectrum at 0x7f3382189a90>,
#  <__main__.Spectrum at 0x7f3382189be0>,
#  <__main__.Spectrum at 0x7f3382189d30>,
#  <__main__.Spectrum at 0x7f3382189e80>,
#  <__main__.Spectrum at 0x7f3382189fd0>,
#  <__main__.Spectrum at 0x7f3382190160>,
#  <__main__.Spectrum at 0x7f33821902b0>,
#  <__main__.Spectrum at 0x7f3382190400>,
#  <__main__.Spectrum at 0x7f3382190550>,
#  <__main__.Spectrum at 0x7f33821906a0>,
#  <__main__.Spectrum at 0x7f33821907f0>,
#  <__main__.Spectrum at 0x7f3382190940>,
#  <__main__.Spectrum at 0x7f3382190a90>,
#  <__main__.Spectrum at 0x7f3382190be0>,
#  <__main__.Spectrum at 0x7f3382190d30>,
#  <__main__.Spectrum at 0x7f3382190e80>,
#  <__main__.Spectrum at 0x7f3382190fd0>,
#  <__main__.Spectrum at 0x7f3382197430>,
#  <__main__.Spectrum at 0x7f3382197160>,
#  <__main__.Spectrum at 0x7f33821972b0>,
#  <__main__.Spectrum at 0x7f3382197400>,
#  <__main__.Spectrum at 0x7f3382197580>,
#  <__main__.Spectrum at 0x7f33821976d0>,
#  <__main__.Spectrum at 0x7f3382197820>,
#  <__main__.Spectrum at 0x7f3382197970>,
#  <__main__.Spectrum at 0x7f3382197ac0>,
#  <__main__.Spectrum at 0x7f3382197c10>,
#  <__main__.Spectrum at 0x7f3382197d60>,
#  <__main__.Spectrum at 0x7f3382197eb0>,
#  <__main__.Spectrum at 0x7f338219f040>,
#  <__main__.Spectrum at 0x7f338219f190>,
#  <__main__.Spectrum at 0x7f338219f2e0>,
#  <__main__.Spectrum at 0x7f338219f430>,
#  <__main__.Spectrum at 0x7f338219f580>,
#  <__main__.Spectrum at 0x7f338219f6d0>,
#  <__main__.Spectrum at 0x7f338219f820>,
#  <__main__.Spectrum at 0x7f338219f970>,
#  <__main__.Spectrum at 0x7f338219fac0>,
#  <__main__.Spectrum at 0x7f338219fc10>,
#  <__main__.Spectrum at 0x7f338219fd90>,
#  <__main__.Spectrum at 0x7f338219fee0>,
#  <__main__.Spectrum at 0x7f3382126070>,
#  <__main__.Spectrum at 0x7f33821261c0>,
#  <__main__.Spectrum at 0x7f3382126310>,
#  <__main__.Spectrum at 0x7f3382126460>,
#  <__main__.Spectrum at 0x7f33821265b0>,
#  <__main__.Spectrum at 0x7f3382126700>,
#  <__main__.Spectrum at 0x7f3382126850>,
#  <__main__.Spectrum at 0x7f33821269a0>,
#  <__main__.Spectrum at 0x7f3382126af0>,
#  <__main__.Spectrum at 0x7f3382126c40>,
#  <__main__.Spectrum at 0x7f3382126d90>,
#  <__main__.Spectrum at 0x7f3382126ee0>,
#  <__main__.Spectrum at 0x7f338212d070>,
#  <__main__.Spectrum at 0x7f338212d1c0>,
#  <__main__.Spectrum at 0x7f338212d310>,
#  <__main__.Spectrum at 0x7f338212d460>,
#  <__main__.Spectrum at 0x7f338212d5b0>,
#  <__main__.Spectrum at 0x7f338212d700>,
#  <__main__.Spectrum at 0x7f338212d850>,
#  <__main__.Spectrum at 0x7f338212d9a0>,
#  <__main__.Spectrum at 0x7f338212daf0>,
#  <__main__.Spectrum at 0x7f338212dc40>,
#  <__main__.Spectrum at 0x7f338212dd90>,
#  <__main__.Spectrum at 0x7f338212dee0>,
#  <__main__.Spectrum at 0x7f338238fee0>,
#  <__main__.Spectrum at 0x7f3382137070>,
#  <__main__.Spectrum at 0x7f3382137310>,
#  <__main__.Spectrum at 0x7f33821375b0>,
#  <__main__.Spectrum at 0x7f33821371c0>,
#  <__main__.Spectrum at 0x7f3382137850>,
#  <__main__.Spectrum at 0x7f3382137460>,
#  <__main__.Spectrum at 0x7f3382137a90>,
#  <__main__.Spectrum at 0x7f3382137be0>,
#  <__main__.Spectrum at 0x7f3382137d30>,
#  <__main__.Spectrum at 0x7f3382137e80>,
#  <__main__.Spectrum at 0x7f3382137fd0>,
#  <__main__.Spectrum at 0x7f338213f160>,
#  <__main__.Spectrum at 0x7f338213f2b0>,
#  <__main__.Spectrum at 0x7f338213f400>,
#  <__main__.Spectrum at 0x7f338213f550>,
#  <__main__.Spectrum at 0x7f338213f6a0>,
#  <__main__.Spectrum at 0x7f338213f7f0>,
#  <__main__.Spectrum at 0x7f338213f940>,
#  <__main__.Spectrum at 0x7f338213fa90>,
#  <__main__.Spectrum at 0x7f338213fbe0>,
#  <__main__.Spectrum at 0x7f338213fd30>,
#  <__main__.Spectrum at 0x7f338213fe80>,
#  <__main__.Spectrum at 0x7f338213ffd0>,
#  <__main__.Spectrum at 0x7f338223d2b0>,
#  <__main__.Spectrum at 0x7f338223dc10>,
#  <__main__.Spectrum at 0x7f338223d070>,
#  <__main__.Spectrum at 0x7f33821452b0>,
#  <__main__.Spectrum at 0x7f3382145160>,
#  <__main__.Spectrum at 0x7f3382145550>,
#  <__main__.Spectrum at 0x7f3382145400>,
#  <__main__.Spectrum at 0x7f3382145be0>,
#  <__main__.Spectrum at 0x7f3382145940>,
#  <__main__.Spectrum at 0x7f33821457f0>,
#  <__main__.Spectrum at 0x7f3382145a90>,
#  <__main__.Spectrum at 0x7f3382145f70>,
#  <__main__.Spectrum at 0x7f338214d100>,
#  <__main__.Spectrum at 0x7f338214d250>,
#  <__main__.Spectrum at 0x7f338214d3a0>,
#  <__main__.Spectrum at 0x7f338214d4f0>,
#  <__main__.Spectrum at 0x7f338214d640>,
#  <__main__.Spectrum at 0x7f338214d790>,
#  <__main__.Spectrum at 0x7f338214d8e0>,
#  <__main__.Spectrum at 0x7f338214da30>,
#  <__main__.Spectrum at 0x7f338214db80>,
#  <__main__.Spectrum at 0x7f338214dcd0>,
#  <__main__.Spectrum at 0x7f338214de20>,
#  <__main__.Spectrum at 0x7f338214df70>,
#  <__main__.Spectrum at 0x7f3382154100>,
#  <__main__.Spectrum at 0x7f3382154250>,
#  <__main__.Spectrum at 0x7f33821543a0>,
#  <__main__.Spectrum at 0x7f33821544f0>,
#  <__main__.Spectrum at 0x7f3382154640>,
#  <__main__.Spectrum at 0x7f3382154790>,
#  <__main__.Spectrum at 0x7f33821548e0>,
#  <__main__.Spectrum at 0x7f3382154a30>,
#  <__main__.Spectrum at 0x7f3382154b80>,
#  <__main__.Spectrum at 0x7f3382154cd0>,
#  <__main__.Spectrum at 0x7f3382154e20>,
#  <__main__.Spectrum at 0x7f3382154f70>,
#  <__main__.Spectrum at 0x7f338215b100>,
#  <__main__.Spectrum at 0x7f338215b250>,
#  <__main__.Spectrum at 0x7f338215b3a0>,
#  <__main__.Spectrum at 0x7f338215b4f0>,
#  <__main__.Spectrum at 0x7f338215b640>,
#  <__main__.Spectrum at 0x7f338215b790>,
#  <__main__.Spectrum at 0x7f338215b8e0>,
#  <__main__.Spectrum at 0x7f338215ba30>,
#  <__main__.Spectrum at 0x7f338215bb80>,
#  <__main__.Spectrum at 0x7f338215bcd0>,
#  <__main__.Spectrum at 0x7f338215be20>,
#  <__main__.Spectrum at 0x7f338215bf70>,
#  <__main__.Spectrum at 0x7f33820e4100>,
#  <__main__.Spectrum at 0x7f33820e4250>,
#  <__main__.Spectrum at 0x7f33820e43a0>,
#  <__main__.Spectrum at 0x7f33820e44f0>,
#  <__main__.Spectrum at 0x7f33820e4640>,
#  <__main__.Spectrum at 0x7f33820e4790>,
#  <__main__.Spectrum at 0x7f33820e48e0>,
#  <__main__.Spectrum at 0x7f33820e4a30>,
#  <__main__.Spectrum at 0x7f33820e4b80>,
#  <__main__.Spectrum at 0x7f33820e4cd0>,
#  <__main__.Spectrum at 0x7f33820e4e20>,
#  <__main__.Spectrum at 0x7f33820e4f70>,
#  <__main__.Spectrum at 0x7f33821f4880>,
#  <__main__.Spectrum at 0x7f33821f49d0>,
#  <__main__.Spectrum at 0x7f33821f4940>,
#  <__main__.Spectrum at 0x7f33821f48e0>,
#  <__main__.Spectrum at 0x7f33821f4160>,
#  <__main__.Spectrum at 0x7f3386e24eb0>,
#  <__main__.Spectrum at 0x7f33820eb250>,
#  <__main__.Spectrum at 0x7f33820eb100>,
#  <__main__.Spectrum at 0x7f33820eb580>,
#  <__main__.Spectrum at 0x7f33820eb6d0>,
#  <__main__.Spectrum at 0x7f33820eb820>,
#  <__main__.Spectrum at 0x7f33820eb970>,
#  <__main__.Spectrum at 0x7f33820ebac0>,
#  <__main__.Spectrum at 0x7f33820ebc10>,
#  <__main__.Spectrum at 0x7f33820ebd60>,
#  <__main__.Spectrum at 0x7f33820ebeb0>,
#  <__main__.Spectrum at 0x7f33820f3040>,
#  <__main__.Spectrum at 0x7f33820f3190>,
#  <__main__.Spectrum at 0x7f33820f32e0>,
#  <__main__.Spectrum at 0x7f33820f3430>,
#  <__main__.Spectrum at 0x7f33820f3580>,
#  <__main__.Spectrum at 0x7f33820f36d0>,
#  <__main__.Spectrum at 0x7f33820f3820>,
#  <__main__.Spectrum at 0x7f33820f3970>,
#  <__main__.Spectrum at 0x7f33820f3ac0>,
#  <__main__.Spectrum at 0x7f33820f3c10>,
#  <__main__.Spectrum at 0x7f33820f3d60>,
#  <__main__.Spectrum at 0x7f33820f3eb0>,
#  <__main__.Spectrum at 0x7f33820fa040>,
#  <__main__.Spectrum at 0x7f33820fa1f0>,
#  <__main__.Spectrum at 0x7f33820fa3a0>,
#  <__main__.Spectrum at 0x7f33820fa550>,
#  <__main__.Spectrum at 0x7f33820fa700>,
#  <__main__.Spectrum at 0x7f33820fa8b0>,
#  <__main__.Spectrum at 0x7f33820faa60>,
#  <__main__.Spectrum at 0x7f33820fac10>,
#  <__main__.Spectrum at 0x7f33820fadc0>,
#  <__main__.Spectrum at 0x7f33820faf70>,
#  <__main__.Spectrum at 0x7f33820ff160>,
#  <__main__.Spectrum at 0x7f33820ff310>,
#  <__main__.Spectrum at 0x7f33820ff4c0>,
#  <__main__.Spectrum at 0x7f33820ff670>,
#  <__main__.Spectrum at 0x7f33820ff820>,
#  <__main__.Spectrum at 0x7f33820ff9d0>,
#  <__main__.Spectrum at 0x7f33820ffb80>,
#  <__main__.Spectrum at 0x7f33820ffd30>,
#  <__main__.Spectrum at 0x7f33820ffee0>,
#  <__main__.Spectrum at 0x7f33821050d0>,
#  <__main__.Spectrum at 0x7f3382105280>,
#  <__main__.Spectrum at 0x7f3382105430>,
#  <__main__.Spectrum at 0x7f33821055e0>,
#  <__main__.Spectrum at 0x7f3382105790>,
#  <__main__.Spectrum at 0x7f3382105940>,
#  <__main__.Spectrum at 0x7f3382105af0>,
#  <__main__.Spectrum at 0x7f3382105ca0>,
#  <__main__.Spectrum at 0x7f3382105e50>,
#  <__main__.Spectrum at 0x7f338210b040>,
#  <__main__.Spectrum at 0x7f338210b1f0>,
#  <__main__.Spectrum at 0x7f338210b3a0>,
#  <__main__.Spectrum at 0x7f338210b550>,
#  <__main__.Spectrum at 0x7f338210b700>,
#  <__main__.Spectrum at 0x7f338210b8b0>,
#  <__main__.Spectrum at 0x7f338210ba60>,
#  <__main__.Spectrum at 0x7f338210bc10>,
#  <__main__.Spectrum at 0x7f338210bdc0>,
#  <__main__.Spectrum at 0x7f338210bf70>,
#  <__main__.Spectrum at 0x7f3382110160>,
#  <__main__.Spectrum at 0x7f3382110310>,
#  <__main__.Spectrum at 0x7f33821104f0>,
#  <__main__.Spectrum at 0x7f33821106a0>,
#  <__main__.Spectrum at 0x7f3382110850>,
#  <__main__.Spectrum at 0x7f3382110a00>,
#  <__main__.Spectrum at 0x7f3382110bb0>,
#  <__main__.Spectrum at 0x7f3382110d60>,
#  <__main__.Spectrum at 0x7f3382110f10>,
#  <__main__.Spectrum at 0x7f3382116100>,
#  <__main__.Spectrum at 0x7f33821162b0>,
#  <__main__.Spectrum at 0x7f3382116460>,
#  <__main__.Spectrum at 0x7f3382116610>,
#  <__main__.Spectrum at 0x7f33821167c0>,
#  <__main__.Spectrum at 0x7f3382116970>,
#  <__main__.Spectrum at 0x7f3382116b20>,
#  <__main__.Spectrum at 0x7f3382116cd0>,
#  <__main__.Spectrum at 0x7f3382116e80>,
#  <__main__.Spectrum at 0x7f338211c070>,
#  <__main__.Spectrum at 0x7f338211c220>,
#  <__main__.Spectrum at 0x7f338211c3d0>,
#  <__main__.Spectrum at 0x7f338211c580>,
#  <__main__.Spectrum at 0x7f338211c730>,
#  <__main__.Spectrum at 0x7f338211c8e0>,
#  <__main__.Spectrum at 0x7f338211ca90>,
#  <__main__.Spectrum at 0x7f338211cc40>,
#  <__main__.Spectrum at 0x7f338211cdf0>,
#  <__main__.Spectrum at 0x7f338211cfa0>,
#  <__main__.Spectrum at 0x7f3382121190>,
#  <__main__.Spectrum at 0x7f3382121340>,
#  <__main__.Spectrum at 0x7f33821214f0>,
#  <__main__.Spectrum at 0x7f33821216a0>,
#  <__main__.Spectrum at 0x7f3382121850>,
#  <__main__.Spectrum at 0x7f3382121a00>,
#  <__main__.Spectrum at 0x7f3382121bb0>,
#  <__main__.Spectrum at 0x7f3382121d60>,
#  <__main__.Spectrum at 0x7f3382121f10>,
#  <__main__.Spectrum at 0x7f33b842c760>,
#  <__main__.Spectrum at 0x7f33820a8100>,
#  <__main__.Spectrum at 0x7f33820a8460>,
#  <__main__.Spectrum at 0x7f33820a82b0>,
#  <__main__.Spectrum at 0x7f33820a87c0>,
#  <__main__.Spectrum at 0x7f33820a8610>,
#  <__main__.Spectrum at 0x7f33820a8b20>,
#  <__main__.Spectrum at 0x7f33820a8970>,
#  <__main__.Spectrum at 0x7f33820a8cd0>,
#  <__main__.Spectrum at 0x7f33820a8fd0>,
#  <__main__.Spectrum at 0x7f33820b01c0>,
#  <__main__.Spectrum at 0x7f33820b0370>,
#  <__main__.Spectrum at 0x7f33820b0520>,
#  <__main__.Spectrum at 0x7f33820b06d0>,
#  <__main__.Spectrum at 0x7f33820b0880>,
#  <__main__.Spectrum at 0x7f33820b0a30>,
#  <__main__.Spectrum at 0x7f33820b0be0>,
#  <__main__.Spectrum at 0x7f33820b0d90>,
#  <__main__.Spectrum at 0x7f33820b0f70>,
#  <__main__.Spectrum at 0x7f33820b5160>,
#  <__main__.Spectrum at 0x7f33820b5310>,
#  <__main__.Spectrum at 0x7f33820b54c0>,
#  <__main__.Spectrum at 0x7f33820b5670>,
#  <__main__.Spectrum at 0x7f33820b5820>,
#  <__main__.Spectrum at 0x7f33820b59d0>,
#  <__main__.Spectrum at 0x7f33820b5b80>,
#  <__main__.Spectrum at 0x7f33820b5d30>,
#  <__main__.Spectrum at 0x7f33820b5ee0>,
#  <__main__.Spectrum at 0x7f3382234d60>,
#  <__main__.Spectrum at 0x7f3382164130>,
#  <__main__.Spectrum at 0x7f3382164280>,
#  <__main__.Spectrum at 0x7f33821643d0>,
#  <__main__.Spectrum at 0x7f3382164520>,
#  <__main__.Spectrum at 0x7f3382164700>,
#  <__main__.Spectrum at 0x7f3382164850>,
#  <__main__.Spectrum at 0x7f33821649a0>,
#  <__main__.Spectrum at 0x7f338230bfd0>,
#  <__main__.Spectrum at 0x7f3382164c40>,
#  <__main__.Spectrum at 0x7f33822643d0>,
#  <__main__.Spectrum at 0x7f3382164ee0>,
#  <__main__.Spectrum at 0x7f3382164af0>,
#  <__main__.Spectrum at 0x7f3382164d90>,
#  <__main__.Spectrum at 0x7f3382164610>,
#  <__main__.Spectrum at 0x7f33821645b0>,
#  <__main__.Spectrum at 0x7f33820bb0d0>,
#  <__main__.Spectrum at 0x7f33820bb430>,
#  <__main__.Spectrum at 0x7f33820bb790>,
#  <__main__.Spectrum at 0x7f33820bb280>,
#  <__main__.Spectrum at 0x7f33820bbaf0>,
#  <__main__.Spectrum at 0x7f33820bb5e0>,
#  <__main__.Spectrum at 0x7f33820bb940>,
#  <__main__.Spectrum at 0x7f33820bbee0>,
#  <__main__.Spectrum at 0x7f33820c1070>,
#  <__main__.Spectrum at 0x7f33820c1220>,
#  <__main__.Spectrum at 0x7f33820c13d0>,
#  <__main__.Spectrum at 0x7f33820c1580>,
#  <__main__.Spectrum at 0x7f33820c1730>,
#  <__main__.Spectrum at 0x7f33820c18e0>,
#  <__main__.Spectrum at 0x7f33820c1a90>,
#  <__main__.Spectrum at 0x7f33820c1c40>,
#  <__main__.Spectrum at 0x7f33820c1df0>,
#  <__main__.Spectrum at 0x7f33820c1fa0>,
#  <__main__.Spectrum at 0x7f33820c8190>,
#  <__main__.Spectrum at 0x7f33820c8340>,
#  <__main__.Spectrum at 0x7f33820c84f0>,
#  <__main__.Spectrum at 0x7f33820c86a0>,
#  <__main__.Spectrum at 0x7f33820c8850>,
#  <__main__.Spectrum at 0x7f33820c8a00>,
#  <__main__.Spectrum at 0x7f33820c8bb0>,
#  <__main__.Spectrum at 0x7f33820c8d60>,
#  <__main__.Spectrum at 0x7f33820c8f10>,
#  <__main__.Spectrum at 0x7f33822879d0>,
#  <__main__.Spectrum at 0x7f33820cd2b0>,
#  <__main__.Spectrum at 0x7f33820cd100>,
#  <__main__.Spectrum at 0x7f3382331c10>,
#  <__main__.Spectrum at 0x7f33820cd460>,
#  <__main__.Spectrum at 0x7f3382331d00>,
#  <__main__.Spectrum at 0x7f33820cd7c0>,
#  <__main__.Spectrum at 0x7f33821b56d0>,
#  <__main__.Spectrum at 0x7f33820cddf0>,
#  <__main__.Spectrum at 0x7f33821b55e0>,
#  <__main__.Spectrum at 0x7f33820cd610>,
#  <__main__.Spectrum at 0x7f33820cd970>,
#  <__main__.Spectrum at 0x7f33820cdc10>,
#  <__main__.Spectrum at 0x7f33820cdfa0>,
#  <__main__.Spectrum at 0x7f33820d2190>,
#  <__main__.Spectrum at 0x7f33820d2340>,
#  <__main__.Spectrum at 0x7f33820d24f0>,
#  <__main__.Spectrum at 0x7f33820d26a0>,
#  <__main__.Spectrum at 0x7f33820d2850>,
#  <__main__.Spectrum at 0x7f33820d2a00>,
#  <__main__.Spectrum at 0x7f33820d2bb0>,
#  <__main__.Spectrum at 0x7f33820d2d60>,
#  <__main__.Spectrum at 0x7f33820d2f10>,
#  <__main__.Spectrum at 0x7f33820d8100>,
#  <__main__.Spectrum at 0x7f33820d82b0>,
#  <__main__.Spectrum at 0x7f33820d8460>,
#  <__main__.Spectrum at 0x7f33820d8610>,
#  <__main__.Spectrum at 0x7f33820d87c0>,
#  <__main__.Spectrum at 0x7f33820d8970>,
#  <__main__.Spectrum at 0x7f33820d8b20>,
#  <__main__.Spectrum at 0x7f33820d8cd0>,
#  <__main__.Spectrum at 0x7f33820d8e80>,
#  <__main__.Spectrum at 0x7f33820dd070>,
#  <__main__.Spectrum at 0x7f33820dd220>,
#  <__main__.Spectrum at 0x7f33820dd3d0>,
#  <__main__.Spectrum at 0x7f33820dd580>,
#  <__main__.Spectrum at 0x7f33820dd730>,
#  <__main__.Spectrum at 0x7f33820dd8e0>,
#  <__main__.Spectrum at 0x7f33820dda90>,
#  <__main__.Spectrum at 0x7f33820ddc40>,
#  <__main__.Spectrum at 0x7f33820dddf0>,
#  <__main__.Spectrum at 0x7f33820ddfa0>,
#  <__main__.Spectrum at 0x7f3382064190>,
#  <__main__.Spectrum at 0x7f3382064340>,
#  <__main__.Spectrum at 0x7f33820644f0>,
#  <__main__.Spectrum at 0x7f33820646a0>,
#  <__main__.Spectrum at 0x7f3382064850>,
#  <__main__.Spectrum at 0x7f3382064a00>,
#  <__main__.Spectrum at 0x7f3382064bb0>,
#  <__main__.Spectrum at 0x7f3382064d60>,
#  <__main__.Spectrum at 0x7f3382064f10>,
#  <__main__.Spectrum at 0x7f3382331dc0>,
#  <__main__.Spectrum at 0x7f338206a100>,
#  <__main__.Spectrum at 0x7f338206a2b0>,
#  <__main__.Spectrum at 0x7f338206a460>,
#  <__main__.Spectrum at 0x7f338206a610>,
#  <__main__.Spectrum at 0x7f338206a7c0>,
#  <__main__.Spectrum at 0x7f338206a970>,
#  <__main__.Spectrum at 0x7f338206ab20>,
#  <__main__.Spectrum at 0x7f338206acd0>,
#  <__main__.Spectrum at 0x7f338206ae80>,
#  <__main__.Spectrum at 0x7f338206f070>,
#  <__main__.Spectrum at 0x7f338206f220>,
#  <__main__.Spectrum at 0x7f338206f3d0>,
#  <__main__.Spectrum at 0x7f338206f580>,
#  <__main__.Spectrum at 0x7f338206f730>,
#  <__main__.Spectrum at 0x7f338206f8e0>,
#  <__main__.Spectrum at 0x7f338206fa90>,
#  <__main__.Spectrum at 0x7f338206fc40>,
#  <__main__.Spectrum at 0x7f338206fdf0>,
#  <__main__.Spectrum at 0x7f338206ffa0>,
#  <__main__.Spectrum at 0x7f3382075190>,
#  <__main__.Spectrum at 0x7f3382075340>,
#  <__main__.Spectrum at 0x7f33820754f0>,
#  <__main__.Spectrum at 0x7f33820756a0>,
#  <__main__.Spectrum at 0x7f3382075850>,
#  <__main__.Spectrum at 0x7f3382075a00>,
#  <__main__.Spectrum at 0x7f3382075bb0>,
#  <__main__.Spectrum at 0x7f3382075d60>,
#  <__main__.Spectrum at 0x7f3382075f10>,
#  <__main__.Spectrum at 0x7f338207c100>,
#  <__main__.Spectrum at 0x7f338207c2b0>,
#  <__main__.Spectrum at 0x7f338207c460>,
#  <__main__.Spectrum at 0x7f338207c610>,
#  <__main__.Spectrum at 0x7f338207c7c0>,
#  <__main__.Spectrum at 0x7f338207c970>,
#  <__main__.Spectrum at 0x7f338207cb20>,
#  <__main__.Spectrum at 0x7f338207ccd0>,
#  <__main__.Spectrum at 0x7f338207ce80>,
#  <__main__.Spectrum at 0x7f3382083070>,
#  <__main__.Spectrum at 0x7f3382083220>,
#  <__main__.Spectrum at 0x7f3382083730>,
#  <__main__.Spectrum at 0x7f3382083580>,
#  <__main__.Spectrum at 0x7f3382083a90>,
#  <__main__.Spectrum at 0x7f33820838e0>,
#  <__main__.Spectrum at 0x7f3382083b80>,
#  <__main__.Spectrum at 0x7f3382083c70>,
#  <__main__.Spectrum at 0x7f3382083e20>,
#  <__main__.Spectrum at 0x7f3382083fd0>,
#  <__main__.Spectrum at 0x7f33820871c0>,
#  <__main__.Spectrum at 0x7f3382087370>,
#  <__main__.Spectrum at 0x7f3382087520>,
#  <__main__.Spectrum at 0x7f33820876d0>,
#  <__main__.Spectrum at 0x7f3382087880>,
#  <__main__.Spectrum at 0x7f3382087a30>,
#  <__main__.Spectrum at 0x7f3382087be0>,
#  <__main__.Spectrum at 0x7f3382087d90>,
#  <__main__.Spectrum at 0x7f3382087f40>]

# %% [markdown]
# ## Part 7: Make a Damn Plot (10 points)
#
# &#9989; **Select one of your spectrum objects and use it to make a plot. Your plot should have Wavelength on the x-axis and flux on the y-axis.**
#
# *Note: You can complete this problem even if you did not complete Part 6. As long as you have A spectrum object.*

# %%
#Write your code here
from matplotlib import pyplot as plt
plt.plot(spectrum_objects[0].get_wavelength(),spectrum_objects[0].get_flux())
plt.xlabel("Wavelength")
plt.ylabel("Flux")
plt.title("Wavelength vs Flux")
# Out:
# Text(0.5, 1.0, 'Wavelength vs Flux')

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## You're done! Congrats on finishing your CMSE 202 Midterm!
#
# Make sure all of your changes to your repository are committed and pushed to GitHub. Also upload a copy of this notebook to the dropbox on D2L in case something went wrong with your repository or if you couldn't get the repository to work.
